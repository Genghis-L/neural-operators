# %% [markdown]
# # Data generation for Navier Stokes
#
# The Navier Stokes equation is given by
#
# $$
# \begin{align}
# \partial_t w(x,t) + u(x,t) \cdot \nabla w(x,t) &= \nu \Delta w(x,t) + f(x)\\
# \nabla \cdot u(x,t) &= 0\\
# w(x,0) &= w_0(x)
# \end{align}
# $$
#
# where $w(x,t)$ is the velocity field, $u(x,t)$ is the vortex field, $\nu$ is the viscosity, and $f(x)$ is the forcing term.

# %% [markdown]
# ## Libraries

# %%
# Setup paths to import modules
import sys
import os

# Add parent directory to path
parent_dir = os.path.abspath('..')
if parent_dir not in sys.path:
    sys.path.insert(0, parent_dir)

print(f"Added {parent_dir} to sys.path")
# Out:
# Added /Users/genghisluo/Downloads/Fourier-Neural-Operator-main to sys.path

# %%
# PyTorch
import torch
# Math
import math
# Scipy
import scipy.io
# Timeit for measuring execution time
from timeit import default_timer
# Matplotlib
import matplotlib.pyplot as plt

# Get the device
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# Print GPUs device name
if torch.cuda.is_available():
    for i in range(torch.cuda.device_count()):
        print("GPU",i,":",torch.cuda.get_device_name(i))

# %% [markdown]
# ## Function to create random initial conditions

# %%
class GaussianRF(object):

    def __init__(self, dim, size, alpha=2, tau=3, sigma=None, boundary="periodic", device=None):

        self.dim = dim
        self.device = device

        if sigma is None:
            sigma = tau**(0.5*(2*alpha - self.dim))

        k_max = size//2

        if dim == 1:
            k = torch.cat((torch.arange(start=0, end=k_max, step=1, device=device), torch.arange(start=-k_max, end=0, step=1, device=device)), 0)

            self.sqrt_eig = size*math.sqrt(2.0)*sigma*((4*(math.pi**2)*(k**2) + tau**2)**(-alpha/2.0))
            self.sqrt_eig[0] = 0.0

        elif dim == 2:
            wavenumers = torch.cat((torch.arange(start=0, end=k_max, step=1, device=device), \
                                    torch.arange(start=-k_max, end=0, step=1, device=device)), 0).repeat(size,1)

            k_x = wavenumers.transpose(0,1)
            k_y = wavenumers

            self.sqrt_eig = (size**2)*math.sqrt(2.0)*sigma*((4*(math.pi**2)*(k_x**2 + k_y**2) + tau**2)**(-alpha/2.0))
            self.sqrt_eig[0,0] = 0.0

        elif dim == 3:
            wavenumers = torch.cat((torch.arange(start=0, end=k_max, step=1, device=device), \
                                    torch.arange(start=-k_max, end=0, step=1, device=device)), 0).repeat(size,size,1)

            k_x = wavenumers.transpose(1,2)
            k_y = wavenumers
            k_z = wavenumers.transpose(0,2)

            self.sqrt_eig = (size**3)*math.sqrt(2.0)*sigma*((4*(math.pi**2)*(k_x**2 + k_y**2 + k_z**2) + tau**2)**(-alpha/2.0))
            self.sqrt_eig[0,0,0] = 0.0

        self.size = []
        for j in range(self.dim):
            self.size.append(size)

        self.size = tuple(self.size)

    def sample(self, N):

        coeff = torch.randn(N, *self.size, dtype=torch.cfloat, device=self.device)
        coeff = self.sqrt_eig * coeff

        return torch.fft.ifftn(coeff, dim=list(range(-1, -self.dim - 1, -1))).real

# %%
gauss = GaussianRF(dim=2, size=64, alpha=2, tau=3, sigma=1, device=device)

# %%
# Generate a sample
sample = gauss.sample(1)

# %%
# Plot the sample
plt.imshow(sample[0].cpu().numpy(), cmap='viridis')
plt.show()

# %% [markdown]
# ## Function to solve Navier Stokes

# %%
# Function to solve Navier-Stokes equation in 2D
def navier_stokes_2d(w0, f, visc, T, delta_t=1e-4, record_steps=1):

    # Grid size - it must be power of 2
    N = w0.size()[-1]

    # Max wavenumber
    k_max = math.floor(N/2.0)

    # Total number of steps
    steps = math.ceil(T/delta_t)

    # Initial vortex field in Fourier space
    w_h = torch.fft.rfft2(w0)

    # Forcing field in Fourier space
    f_h = torch.fft.rfft2(f)

    # If the same forcing for the whole batch
    if len(f_h.size()) < len(w_h.size()):
        f_h = torch.unsqueeze(f_h, 0)

    # Save the solution every certain number of steps
    record_time = math.floor(steps/record_steps)

    # Wave numbers in y-direction
    k_y = torch.cat((torch.arange(start=0, end=k_max, step=1, device=w0.device), torch.arange(start=-k_max, end=0, step=1, device=w0.device)), 0).repeat(N,1)
    
    # Wave numbers in x-direction
    k_x = k_y.transpose(0,1)

    # Remove redundant modes
    k_x = k_x[..., :k_max + 1]
    k_y = k_y[..., :k_max + 1]

    # Negative of the Laplacian in Fourier space
    lap = 4*(math.pi**2)*(k_x**2 + k_y**2)
    lap[0,0] = 1.0
    
    # Dealiasing mask: 2/3 rule
    dealias = torch.unsqueeze(torch.logical_and(torch.abs(k_y) <= (2.0/3.0)*k_max, torch.abs(k_x) <= (2.0/3.0)*k_max).float(), 0)

    # Save the solution and time
    sol = torch.zeros(*w0.size(), record_steps, device=w0.device)
    sol_t = torch.zeros(record_steps, device=w0.device)

    #Record counter
    c = 0
    
    #Physical time
    t = 0.0
    for j in range(steps):
        
        #Stream function in Fourier space: solve Poisson equation
        psi_h = w_h / lap

        #Velocity field in x-direction = psi_y
        q = 2. * math.pi * k_y * 1j * psi_h
        q = torch.fft.irfft2(q, s=(N, N))

        #Velocity field in y-direction = -psi_x
        v = -2. * math.pi * k_x * 1j * psi_h
        v = torch.fft.irfft2(v, s=(N, N))        #Partial x of vorticity
        w_x = 2. * math.pi * k_x * 1j * w_h
        w_x = torch.fft.irfft2(w_x, s=(N, N))

        #Partial y of vorticity
        w_y = 2. * math.pi * k_y * 1j * w_h
        w_y = torch.fft.irfft2(w_y, s=(N, N))

        #Non-linear term (u.grad(w)): compute in physical space then back to Fourier space
        F_h = torch.fft.rfft2(q*w_x + v*w_y)

        #Dealias
        F_h = dealias* F_h

        #Crank-Nicolson update
        w_h = (-delta_t*F_h + delta_t*f_h + (1.0 - 0.5*delta_t*visc*lap)*w_h)/(1.0 + 0.5*delta_t*visc*lap)

        #Update real time (used only for recording)
        t += delta_t

        if (j+1) % record_time == 0:
            #Solution in physical space
            w = torch.fft.irfft2(w_h, s=(N, N))

            #Record solution and time
            sol[...,c] = w
            sol_t[c] = t

            c += 1

    return sol, sol_t

# %% [markdown]
# ## Get data and save to MATLAB file
#
# We are going to generate data for the following parameters:
#
# - $\nu =1\times 10^{-5}$
# - $f(x, y) = 0.1 \sin(2\pi (x+y)) \cos(2\pi (x+y))$
#
# - 64×64 spatial grid

# %%
#Resolution
s = 64

#Number of solutions to generate
N = 1

#Set up 2d GRF with covariance parameters
GRF = GaussianRF(2, s, alpha=2.5, tau=7, device=device)

# Time grid
t = torch.linspace(0, 1, s+1, device=device)
t = t[0:-1]

# Forcing function: 0.1*(sin(2pi(x+y)) + cos(2pi(x+y)))
X,Y = torch.meshgrid(t, t, indexing='ij')
f = 0.1*(torch.sin(2*math.pi*(X + Y)) + torch.cos(2*math.pi*(X + Y)))

#Number of snapshots from solution
record_steps = 1000

#Inputs
a = torch.zeros(N, s, s)
#Solutions
u = torch.zeros(N, s, s, record_steps)

#Solve equations in batches (order of magnitude speed-up)

#Batch size
bsize = 1

c = 0
t0 = default_timer()
for j in range(N//bsize):

    #Sample random feilds
    w0 = GRF.sample(bsize)

    #Solve NS
    sol, sol_t = navier_stokes_2d(w0, f, 1e-5, 100.0, 1e-4, record_steps)

    a[c:(c+bsize),...] = w0
    u[c:(c+bsize),...] = sol

    c += bsize
    t1 = default_timer()
    print(j, c, t1-t0)

scipy.io.savemat('data/ns_data.mat', mdict={'a': a.cpu().numpy(), 'u': u.cpu().numpy(), 't': sol_t.cpu().numpy()})
# Out:
# 0 1 104.073757625

# %%
u.shape
# Out:
# torch.Size([1, 64, 64, 1000])

# %%
plt.imshow(u.cpu().numpy()[0,:,:,150], cmap='viridis')

# %% [markdown]
# ## Check the discrepency between generated solution and stored solution

# %%
from utilities.utils import MatlabFileReader

# %%
# Import FNO model from PyTorch implementation
from FNO.PyTorch.fno import FNO

# Import loss function
from losses.lploss import LpLoss

# Import training utilities
from training.train import train_model

# Import data utilities
from utilities.utils import MatlabFileReader

# Standard libraries
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import torch.nn.functional as F
import numpy as np
import timeit

# Set device
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"Using device: {device}")
# Out:
# Using device: cpu

# %%
mat_obj = MatlabFileReader('data/ns_data.mat')

# %%
mat_data = mat_obj.read_file('u')
mat_data.shape
# Out:
# (1, 64, 64, 1000)

# %%
plt.imshow(mat_data[0,:,:,800], cmap='viridis')

# %% [markdown]
# ## Create GIF Animation of Time Evolution

# %%
import matplotlib
matplotlib.rcParams['animation.embed_limit'] = 200  # Increase to 200 MB

# %%
import matplotlib.animation as animation
from IPython.display import HTML
import numpy as np
import matplotlib.pyplot as plt

# Get the vorticity data
vorticity_data_generated = u.cpu().numpy()[0]  # Generated solution: Shape: (64, 64, 200)
vorticity_data_matlab = mat_data[0]  # MATLAB data: Shape: (64, 64, 200)
num_timesteps = vorticity_data_generated.shape[2]
grid_size = vorticity_data_generated.shape[0]  # 64

# Create figure with 3 subplots (reduced size for better embedding)
fig, axes = plt.subplots(1, 3, figsize=(18, 5), dpi=80)

# Find global min/max for consistent colorbar across all plots
vmin = min(vorticity_data_matlab.min(), vorticity_data_generated.min())
vmax = max(vorticity_data_matlab.max(), vorticity_data_generated.max())

# Initialize the three plots with Y-axis from bottom to top
# First subplot: MATLAB Data
im0 = axes[0].imshow(vorticity_data_matlab[:, :, 0], cmap='viridis', vmin=vmin, vmax=vmax,
                     origin='lower', extent=[0, grid_size, 0, grid_size])
axes[0].set_xlabel('x', fontsize=12)
axes[0].set_ylabel('y', fontsize=12)
axes[0].set_title('MATLAB Data (t=0.00s)', fontsize=14)
cbar0 = fig.colorbar(im0, ax=axes[0], label='Vorticity')

# Second subplot: Generated Solution
im1 = axes[1].imshow(vorticity_data_generated[:, :, 0], cmap='viridis', vmin=vmin, vmax=vmax,
                     origin='lower', extent=[0, grid_size, 0, grid_size])
axes[1].set_xlabel('x', fontsize=12)
axes[1].set_ylabel('y', fontsize=12)
axes[1].set_title('Generated Solution (t=0.00s)', fontsize=14)
cbar1 = fig.colorbar(im1, ax=axes[1], label='Vorticity')

# Third subplot: Difference (Error)
difference = np.abs(vorticity_data_matlab[:, :, 1] - vorticity_data_generated[:, :, 0])
diff_vmax = 0.1  # Set a reasonable max for difference visualization
im2 = axes[2].imshow(difference, cmap='viridis', vmin=0, vmax=diff_vmax,
                     origin='lower', extent=[0, grid_size, 0, grid_size])
axes[2].set_xlabel('x', fontsize=12)
axes[2].set_ylabel('y', fontsize=12)
axes[2].set_title('Step Difference (t=0.00s)', fontsize=14)
cbar2 = fig.colorbar(im2, ax=axes[2], label='Error')

plt.tight_layout()

# Animation update function
def update(frame):
    # Get current time
    current_time = sol_t[frame].cpu().numpy()
    
    # Update MATLAB data
    im0.set_array(vorticity_data_matlab[:, :, frame])
    axes[0].set_title(f'MATLAB Data (t={current_time:.2f}s)', fontsize=14)
    
    # Update generated solution
    im1.set_array(vorticity_data_generated[:, :, frame])
    axes[1].set_title(f'Generated Solution (t={current_time:.2f}s)', fontsize=14)
    
    # Update step difference
    difference = np.abs(vorticity_data_matlab[:, :, frame+1] - vorticity_data_generated[:, :, frame])
    im2.set_array(difference)
    axes[2].set_title(f'Step Difference (t={current_time:.2f}s)', fontsize=14)
    
    return [im0, im1, im2]

# Create animation
anim = animation.FuncAnimation(fig, update, frames=num_timesteps-1, 
                               interval=50, blit=True, repeat=True)

# Close the static figure of the last frame
plt.close(fig)

# Display only the interactive animation
HTML(anim.to_jshtml())

# %%
# save GIF
anim.save('navier_stokes_data.gif', writer='pillow', fps=20, dpi=80)
